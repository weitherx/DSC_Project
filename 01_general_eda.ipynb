# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

# %%
input_folder = Path(r'C:\Users\USER\OneDrive\Documents\DSC_Project\20250517_資料集\工程訂單')
output_folder = Path(r'C:\Users\USER\OneDrive\Documents\DSC_Project\20250517_資料集\工程訂單\工程訂單_report')
output_folder.mkdir(exist_ok=True)

# %%
csv_files = ['main.csv', 'customizations.csv', 'services.csv']

for filename in csv_files:
    csv_path = input_folder / filename
    if not csv_path.exists():
        print(f"File not found: {csv_path}")
        continue
    df = pd.read_csv(csv_path)
    csv_name = csv_path.stem

    num_cols = df.select_dtypes(include='number').columns.tolist()
    cat_cols = df.select_dtypes(include='object').columns.tolist()

    # Datetime detection: treat as datetime if any value parses as datetime
    datetime_cols = []
    for col in df.columns:
        if df[col].dtype == 'object':
            parsed = pd.to_datetime(df[col], format=None, errors='coerce')
            if parsed.notnull().any():
                datetime_cols.append(col)

    cat_cols = [c for c in cat_cols if c not in datetime_cols]


    null_pct = (df.isnull().mean() * 100).round(2)

    # Compose the report (formatted for Obsidian)
    report_lines = []
    report_lines.append(f"# EDA Report for `{csv_name}`\n")
    report_lines.append("---\n")

    # 1. Feature Data Types
    report_lines.append("## 1. Feature Data Types\n")
    report_lines.append(f"**Numerical:** {', '.join(num_cols) if num_cols else 'None'}  \n")
    report_lines.append(f"**Categorical:** {', '.join([c for c in cat_cols if c not in datetime_cols]) if cat_cols else 'None'}  \n")
    report_lines.append(f"**Datetime:** {', '.join(datetime_cols) if datetime_cols else 'None'}\n")
    report_lines.append("\n---\n")

    # 2. Null Percentage of Each Feature
    report_lines.append("## 2. Null Percentage of Each Feature\n")
    report_lines.append(null_pct.to_frame('Null %').to_markdown(index=True))
    report_lines.append("\n---\n")

    # 3. Summary Statistics
    report_lines.append("## 3. Summary Statistics\n")

    # Numerical Features
    if num_cols:
        report_lines.append("### Numerical Features\n")
        report_lines.append(df[num_cols].describe().to_markdown(index=True))
        report_lines.append("\n")
    else:
        report_lines.append("No numerical features found.\n")

    # Categorical Features
    if cat_cols:
        report_lines.append("### Categorical Features\n")
        for col in cat_cols:
            vc = df[col].value_counts().head(10)
            report_lines.append(f"**{col} (Top 10 categories):**\n")
            report_lines.append(vc.to_frame('Count').to_markdown(index=True))
            report_lines.append("\n")
    else:
        report_lines.append("No categorical features found.\n")

    # Datetime Features
    if datetime_cols:
        report_lines.append("### Datetime Features\n")
        for col in datetime_cols:
            parsed = pd.to_datetime(df[col], errors='coerce')
            valid_dates = parsed.dropna()
            report_lines.append(f"**{col}**  ")
            report_lines.append(f"- Non-null count: {parsed.notnull().sum()}")
            valid_dates = pd.to_datetime(df[col], errors='coerce').dropna()
            if not valid_dates.empty:
                # Ensure valid_dates is actually datetime dtype
                valid_dates = pd.Series(valid_dates)
                if hasattr(valid_dates, "dt"):
                    try:
                        valid_dates = valid_dates.dt.tz_localize(None)
                    except AttributeError:
                        # already naive, nothing to do
                        pass
                    report_lines.append(f"- Earliest: {valid_dates.min()}")
                    report_lines.append(f"- Latest: {valid_dates.max()}")
                else:
                    report_lines.append("- Could not parse as datetimelike.")
            else:
                report_lines.append("- No valid datetime values found.")
        else:
            report_lines.append("No datetime features found.\n")

    report_lines.append("---\n")

    # Save Markdown report
    md_path = output_folder / f"{csv_name}_EDA_Report.md"
    with open(md_path, "w", encoding="utf-8") as f:
        f.write("\n".join(report_lines))
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A5W" included an un-recognized timezone "W". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A5J" included an un-recognized timezone "J". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A5X" included an un-recognized timezone "X". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A5F" included an un-recognized timezone "F". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A5K" included an un-recognized timezone "K". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A5G" included an un-recognized timezone "G". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A5E" included an un-recognized timezone "E". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A5L" included an un-recognized timezone "L". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A5Q" included an un-recognized timezone "Q". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A5N" included an un-recognized timezone "N". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A5Y" included an un-recognized timezone "Y". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A5R" included an un-recognized timezone "R". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A5C" included an un-recognized timezone "C". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A5U" included an un-recognized timezone "U". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A5V" included an un-recognized timezone "V". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A9W" included an un-recognized timezone "W". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A9J" included an un-recognized timezone "J". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A9X" included an un-recognized timezone "X". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A9F" included an un-recognized timezone "F". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A9K" included an un-recognized timezone "K". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A9G" included an un-recognized timezone "G". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A9E" included an un-recognized timezone "E". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A9L" included an un-recognized timezone "L". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A9Q" included an un-recognized timezone "Q". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A9N" included an un-recognized timezone "N". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A9Y" included an un-recognized timezone "Y". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A9R" included an un-recognized timezone "R". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A9C" included an un-recognized timezone "C". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A9U" included an un-recognized timezone "U". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A9V" included an un-recognized timezone "V". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A2W" included an un-recognized timezone "W". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A2J" included an un-recognized timezone "J". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A2X" included an un-recognized timezone "X". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A2F" included an un-recognized timezone "F". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A2K" included an un-recognized timezone "K". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A2G" included an un-recognized timezone "G". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A2E" included an un-recognized timezone "E". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A2L" included an un-recognized timezone "L". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A2Q" included an un-recognized timezone "Q". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A2N" included an un-recognized timezone "N". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A2Y" included an un-recognized timezone "Y". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A2R" included an un-recognized timezone "R". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A2C" included an un-recognized timezone "C". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A2U" included an un-recognized timezone "U". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A2V" included an un-recognized timezone "V". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A6W" included an un-recognized timezone "W". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A6J" included an un-recognized timezone "J". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A6X" included an un-recognized timezone "X". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A6F" included an un-recognized timezone "F". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A6K" included an un-recognized timezone "K". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A6G" included an un-recognized timezone "G". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A6E" included an un-recognized timezone "E". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A6L" included an un-recognized timezone "L". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A6Q" included an un-recognized timezone "Q". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A6N" included an un-recognized timezone "N". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A6Y" included an un-recognized timezone "Y". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A6R" included an un-recognized timezone "R". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A6C" included an un-recognized timezone "C". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A6U" included an un-recognized timezone "U". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A6V" included an un-recognized timezone "V". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A3W" included an un-recognized timezone "W". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A3J" included an un-recognized timezone "J". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A3X" included an un-recognized timezone "X". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A3F" included an un-recognized timezone "F". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A3K" included an un-recognized timezone "K". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A3G" included an un-recognized timezone "G". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A3E" included an un-recognized timezone "E". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A3L" included an un-recognized timezone "L". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A3Q" included an un-recognized timezone "Q". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A3N" included an un-recognized timezone "N". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A3Y" included an un-recognized timezone "Y". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A3R" included an un-recognized timezone "R". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A3C" included an un-recognized timezone "C". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A3U" included an un-recognized timezone "U". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A3V" included an un-recognized timezone "V". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A7W" included an un-recognized timezone "W". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A7J" included an un-recognized timezone "J". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A7X" included an un-recognized timezone "X". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A7F" included an un-recognized timezone "F". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A7K" included an un-recognized timezone "K". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A7G" included an un-recognized timezone "G". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A7E" included an un-recognized timezone "E". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A7L" included an un-recognized timezone "L". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A7Q" included an un-recognized timezone "Q". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A7N" included an un-recognized timezone "N". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A7Y" included an un-recognized timezone "Y". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A7R" included an un-recognized timezone "R". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A7C" included an un-recognized timezone "C". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A7U" included an un-recognized timezone "U". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A7V" included an un-recognized timezone "V". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A8W" included an un-recognized timezone "W". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A8J" included an un-recognized timezone "J". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A8X" included an un-recognized timezone "X". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A8F" included an un-recognized timezone "F". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A8K" included an un-recognized timezone "K". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A8G" included an un-recognized timezone "G". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A8E" included an un-recognized timezone "E". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A8L" included an un-recognized timezone "L". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A8Q" included an un-recognized timezone "Q". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A8N" included an un-recognized timezone "N". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A8Y" included an un-recognized timezone "Y". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A8R" included an un-recognized timezone "R". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A8C" included an un-recognized timezone "C". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A8U" included an un-recognized timezone "U". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A8V" included an un-recognized timezone "V". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A1W" included an un-recognized timezone "W". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A1J" included an un-recognized timezone "J". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A1X" included an un-recognized timezone "X". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A1F" included an un-recognized timezone "F". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A1K" included an un-recognized timezone "K". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A1G" included an un-recognized timezone "G". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: Parsed string "000A1E" included an un-recognized timezone "E". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
# ...
#   valid_dates = pd.to_datetime(df[col], errors='coerce').dropna()
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:74: FutureWarning: Parsed string "000H1L" included an un-recognized timezone "L". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   valid_dates = pd.to_datetime(df[col], errors='coerce').dropna()
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:74: FutureWarning: Parsed string "000H1Q" included an un-recognized timezone "Q". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   valid_dates = pd.to_datetime(df[col], errors='coerce').dropna()
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:74: FutureWarning: Parsed string "000H1N" included an un-recognized timezone "N". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   valid_dates = pd.to_datetime(df[col], errors='coerce').dropna()
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:74: FutureWarning: Parsed string "000H1Y" included an un-recognized timezone "Y". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   valid_dates = pd.to_datetime(df[col], errors='coerce').dropna()
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:74: FutureWarning: Parsed string "000H1R" included an un-recognized timezone "R". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   valid_dates = pd.to_datetime(df[col], errors='coerce').dropna()
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:74: FutureWarning: Parsed string "000H1C" included an un-recognized timezone "C". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   valid_dates = pd.to_datetime(df[col], errors='coerce').dropna()
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:74: FutureWarning: Parsed string "000H1U" included an un-recognized timezone "U". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   valid_dates = pd.to_datetime(df[col], errors='coerce').dropna()
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:74: FutureWarning: Parsed string "000H1V" included an un-recognized timezone "V". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   valid_dates = pd.to_datetime(df[col], errors='coerce').dropna()
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:74: FutureWarning: Parsed string "000H4W" included an un-recognized timezone "W". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   valid_dates = pd.to_datetime(df[col], errors='coerce').dropna()
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:74: FutureWarning: Parsed string "000H4J" included an un-recognized timezone "J". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   valid_dates = pd.to_datetime(df[col], errors='coerce').dropna()
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:74: FutureWarning: Parsed string "000H4X" included an un-recognized timezone "X". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   valid_dates = pd.to_datetime(df[col], errors='coerce').dropna()
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:74: FutureWarning: Parsed string "000H4F" included an un-recognized timezone "F". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   valid_dates = pd.to_datetime(df[col], errors='coerce').dropna()
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:74: FutureWarning: Parsed string "000H4K" included an un-recognized timezone "K". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   valid_dates = pd.to_datetime(df[col], errors='coerce').dropna()
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:74: FutureWarning: Parsed string "000H4T" included an un-recognized timezone "T". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   valid_dates = pd.to_datetime(df[col], errors='coerce').dropna()
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:74: FutureWarning: Parsed string "000H4G" included an un-recognized timezone "G". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   valid_dates = pd.to_datetime(df[col], errors='coerce').dropna()
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:74: FutureWarning: Parsed string "000H4E" included an un-recognized timezone "E". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   valid_dates = pd.to_datetime(df[col], errors='coerce').dropna()
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:74: FutureWarning: Parsed string "000H4L" included an un-recognized timezone "L". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   valid_dates = pd.to_datetime(df[col], errors='coerce').dropna()
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:74: FutureWarning: Parsed string "000H4Q" included an un-recognized timezone "Q". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   valid_dates = pd.to_datetime(df[col], errors='coerce').dropna()
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:74: FutureWarning: Parsed string "000H4N" included an un-recognized timezone "N". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   valid_dates = pd.to_datetime(df[col], errors='coerce').dropna()
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:74: FutureWarning: Parsed string "000H4Y" included an un-recognized timezone "Y". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   valid_dates = pd.to_datetime(df[col], errors='coerce').dropna()
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:74: FutureWarning: Parsed string "000H4R" included an un-recognized timezone "R". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   valid_dates = pd.to_datetime(df[col], errors='coerce').dropna()
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:74: FutureWarning: Parsed string "000H4C" included an un-recognized timezone "C". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   valid_dates = pd.to_datetime(df[col], errors='coerce').dropna()
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:74: FutureWarning: Parsed string "000H4U" included an un-recognized timezone "U". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   valid_dates = pd.to_datetime(df[col], errors='coerce').dropna()
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:74: FutureWarning: Parsed string "000H4V" included an un-recognized timezone "V". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   valid_dates = pd.to_datetime(df[col], errors='coerce').dropna()
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:70: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   parsed = pd.to_datetime(df[col], errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:74: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   valid_dates = pd.to_datetime(df[col], errors='coerce').dropna()
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: FutureWarning: In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:70: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   parsed = pd.to_datetime(df[col], errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:70: FutureWarning: In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#   parsed = pd.to_datetime(df[col], errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:74: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   valid_dates = pd.to_datetime(df[col], errors='coerce').dropna()
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:74: FutureWarning: In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#   valid_dates = pd.to_datetime(df[col], errors='coerce').dropna()
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')
# C:\Users\USER\AppData\Local\Temp\ipykernel_10760\767478566.py:18: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   parsed = pd.to_datetime(df[col], format=None, errors='coerce')

# %%
print(f"EDA reports saved to: {output_folder}")
# Out:
# EDA reports saved to: C:\Users\USER\OneDrive\Documents\DSC_Project\20250517_資料集\工程訂單\工程訂單_report
